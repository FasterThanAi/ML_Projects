# %% [markdown]
# <a href="https://colab.research.google.com/github/FasterThanAi/ML_Projects/blob/main/RegressionPlot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tips=sns.load_dataset('tips')

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex') # on x axis value from which i predict. y axis value that i predict
