# %% [markdown]
# <a href="https://colab.research.google.com/github/FasterThanAi/ML_Projects/blob/main/IPL_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e994978f-dae7-42c3-b908-330e19a2533b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e994978f-dae7-42c3-b908-330e19a2533b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv('IPL.csv')

# %%
df.head()
# Out:
#    match_id           date                                         venue  \
# 0         1  March 26,2022                      Wankhede Stadium, Mumbai
# 1         2  March 27,2022                     Brabourne Stadium, Mumbai
# 2         3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3         4  March 28,2022                      Wankhede Stadium, Mumbai
# 4         5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
#
#        team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0    Chennai    Kolkata  Group     Kolkata         Field               131
# 1      Delhi     Mumbai  Group       Delhi         Field               177
# 2   Banglore     Punjab  Group      Punjab         Field               205
# 3    Gujarat    Lucknow  Group     Gujarat         Field               158
# 4  Hyderabad  Rajasthan  Group   Hyderabad         Field               210
#
# ...

# %%
df.shape
# Out:
# (74, 20)

# %%
df.info() # so no null value
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   match_id             74 non-null     int64
#  1   date                 74 non-null     object
#  2   venue                74 non-null     object
#  3   team1                74 non-null     object
#  4   team2                74 non-null     object
#  5   stage                74 non-null     object
#  6   toss_winner          74 non-null     object
#  7   toss_decision        74 non-null     object
#  8   first_ings_score     74 non-null     int64
#  9   first_ings_wkts      74 non-null     int64
#  10  second_ings_score    74 non-null     int64
#  11  second_ings_wkts     74 non-null     int64
#  12  match_winner         74 non-null     object
#  13  won_by               74 non-null     object
#  14  margin               74 non-null     int64
# ...

# %%
print(f"Your rows are ${df.shape[0]} and columns are ${df.shape[1]}")
# Out:
# Your rows are $74 and columns are $20

# %%
df.isna()
# Out:
#     match_id   date  venue  team1  team2  stage  toss_winner  toss_decision  \
# 0      False  False  False  False  False  False        False          False
# 1      False  False  False  False  False  False        False          False
# 2      False  False  False  False  False  False        False          False
# 3      False  False  False  False  False  False        False          False
# 4      False  False  False  False  False  False        False          False
# ..       ...    ...    ...    ...    ...    ...          ...            ...
# 69     False  False  False  False  False  False        False          False
# 70     False  False  False  False  False  False        False          False
# 71     False  False  False  False  False  False        False          False
# 72     False  False  False  False  False  False        False          False
# 73     False  False  False  False  False  False        False          False
#
# ...

# %%
df.isna().sum()
# Out:
# match_id               0
# date                   0
# venue                  0
# team1                  0
# team2                  0
# stage                  0
# toss_winner            0
# toss_decision          0
# first_ings_score       0
# first_ings_wkts        0
# second_ings_score      0
# second_ings_wkts       0
# match_winner           0
# won_by                 0
# margin                 0
# player_of_the_match    0
# top_scorer             0
# highscore              0
# best_bowling           0
# best_bowling_figure    0
# dtype: int64

# %%
# so no null value

# %%
max_matchWinner=df['match_winner'].value_counts()
max_matchWinner
# Out:
# match_winner
# Gujarat      12
# Rajasthan    10
# Banglore      9
# Lucknow       9
# Punjab        7
# Delhi         7
# Kolkata       6
# Hyderabad     6
# Chennai       4
# Mumbai        4
# Name: count, dtype: int64

# %%
sns.barplot(y=max_matchWinner.index,x=max_matchWinner.values,palette='viridis')
# Out:
# <Axes: ylabel='match_winner'>

# %%
sns.countplot(df['match_winner'])
# Out:
# <Axes: xlabel='count', ylabel='match_winner'>

# %% [markdown]
# Toss Desicion Trend

# %%
df.head()
# Out:
#    match_id           date                                         venue  \
# 0         1  March 26,2022                      Wankhede Stadium, Mumbai
# 1         2  March 27,2022                     Brabourne Stadium, Mumbai
# 2         3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3         4  March 28,2022                      Wankhede Stadium, Mumbai
# 4         5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
#
#        team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0    Chennai    Kolkata  Group     Kolkata         Field               131
# 1      Delhi     Mumbai  Group       Delhi         Field               177
# 2   Banglore     Punjab  Group      Punjab         Field               205
# 3    Gujarat    Lucknow  Group     Gujarat         Field               158
# 4  Hyderabad  Rajasthan  Group   Hyderabad         Field               210
#
#    first_ings_wkts  ...    Kolkata      Delhi     Punjab    Gujarat  \
# ...

# %%
sns.countplot(x=df['toss_decision'])
plt.title("Toss Decision Trend")
# Out:
# Text(0.5, 1.0, 'Toss Decision Trend')

# %% [markdown]
# Now calculate after wining the toss how many team won match

# %%
countx=df[df['toss_winner']==df['match_winner']]['match_id'].count()
countx
# Out:
# np.int64(36)

# %%
percentage=(countx/df.shape[0] )*100
ans=round(percentage,2)
ans
# Out:
# np.float64(48.65)

# %% [markdown]
# how team won

# %%
sns.countplot(x=df['won_by'])
plt.title('Won By')
# Out:
# Text(0.5, 1.0, 'Won By')

# %%
count2=df['player_of_the_match'].value_counts().head(10)

# %%
sns.barplot(y=count2.index,x=count2.values)
# Out:
# <Axes: ylabel='player_of_the_match'>

# %%
df['top_scorer'].value_counts().head(2)
# Out:
# top_scorer
# Jos Buttler        7
# Quinton de Kock    5
# Name: count, dtype: int64

# %%
high=df.groupby('top_scorer')['highscore'].sum().sort_values(ascending=False).head(2)
high
# Out:
# top_scorer
# Jos Buttler        651
# Quinton de Kock    377
# Name: highscore, dtype: int64

# %%
high.plot(kind='bar')
# Out:
# <Axes: xlabel='top_scorer'>

# %%
bowler=df.groupby('best_bowling')['best_bowling_figure'].sum().sort_values(ascending=False).head(2)
bowler
bowler
# Out:
# best_bowling
# Andre Russell       4--53--22
# Mukesh Choudhary        4--46
# Name: best_bowling_figure, dtype: object

# %%
#2nd method
df['highest_wicket']=df['best_bowling_figure'].apply(lambda x:x.split('--')[0])
df
# Out:
#     match_id           date                                         venue  \
# 0          1  March 26,2022                      Wankhede Stadium, Mumbai
# 1          2  March 27,2022                     Brabourne Stadium, Mumbai
# 2          3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3          4  March 28,2022                      Wankhede Stadium, Mumbai
# 4          5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
# ..       ...            ...                                           ...
# 69        70    May 22,2022                      Wankhede Stadium, Mumbai
# 70        71    May 24,2022                         Eden Gardens, Kolkata
# 71        72    May 25,2022                         Eden Gardens, Kolkata
# 72        73    May 27,2022              Narendra Modi Stadium, Ahmedabad
# 73        74    May 29,2022              Narendra Modi Stadium, Ahmedabad
#
#         team1      team2    stage toss_winner toss_decision  first_ings_score  \
# ...

# %%
#now we got another col for highest wicket
df['highest_wicket']=df['highest_wicket'].astype(int)

# %% [markdown]
# Group by best_bowling and highest_wicket

# %%
bowl=df.groupby('best_bowling')['highest_wicket'].sum().sort_values(ascending=False).head(10)
bowl
# Out:
# best_bowling
# Yuzvendra Chahal     17
# Jasprit Bumrah       11
# Kuldeep Yadav        11
# Rashid Khan          11
# Josh Hazlewood       10
# Kagiso Rabada        10
# Avesh Khan           10
# Umran Malik           9
# Wanindu Hasaranga     9
# T Natarajan           8
# Name: highest_wicket, dtype: int64

# %%
bowl.plot(kind='barh')
# Out:
# <Axes: ylabel='best_bowling'>

# %%
venue_count=df['venue'].value_counts()
venue_count
# Out:
# venue
# Wankhede Stadium, Mumbai                        21
# Dr DY Patil Sports Academy, Mumbai              20
# Brabourne Stadium, Mumbai                       16
# Maharashtra Cricket Association Stadium,Pune    13
# Eden Gardens, Kolkata                            2
# Narendra Modi Stadium, Ahmedabad                 2
# Name: count, dtype: int64

# %%
sns.barplot(y=venue_count.index, x=venue_count.values)
# Out:
# <Axes: ylabel='venue'>

# %%
run=df[df['won_by']=='Runs'].sort_values(by='margin',ascending=False).head(1)[['match_winner','margin']]
run
# Out:
#    match_winner  margin
# 54      Chennai      91

# %%
#highest score by indivisual
df[df['highscore']==df['highscore'].max()][['top_scorer','highscore']]
# Out:
#          top_scorer  highscore
# 65  Quinton de Kock        140

# %%
df[df['highest_wicket']==df['highest_wicket'].max()][['best_bowling','best_bowling_figure']]
# Out:
#          best_bowling best_bowling_figure
# 29   Yuzvendra Chahal               5--40
# 39        Umran Malik               5--25
# 53  Wanindu Hasaranga               5--18
# 55     Jasprit Bumrah               5--10
